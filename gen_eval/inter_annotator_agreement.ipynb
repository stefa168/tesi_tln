# %%
# %pip install pygamma-agreement cylp pandas numpy tqdm scipy matplotlib ipywidgets
# Out:
# WARNING: Ignoring invalid distribution ~llama (/home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages)
# Requirement already satisfied: pygamma-agreement in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (0.5.9)
# Requirement already satisfied: cylp in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (0.92.3)
# Requirement already satisfied: pandas in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: tqdm in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (4.66.5)
# Requirement already satisfied: scipy in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (1.13.1)
# Requirement already satisfied: matplotlib in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: ipywidgets in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (8.1.5)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (2.4.0)
# Requirement already satisfied: pyannote.core>=4.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (5.0.0)
# Requirement already satisfied: cvxpy>=1.0.25 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (1.6.2)
# Requirement already satisfied: cvxopt==1.3.2 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (1.3.2)
# Requirement already satisfied: numba>=0.54.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (0.61.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (4.12.2)
# Requirement already satisfied: TextGrid>=1.5 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (1.6.1)
# Requirement already satisfied: pympi-ling>=1.69 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (1.70.2)
# Requirement already satisfied: pyannote.database>=4.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pygamma-agreement) (5.1.3)
# Requirement already satisfied: hypothesis in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from cylp) (6.127.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: comm>=0.1.3 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipywidgets) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: osqp>=0.6.2 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from cvxpy>=1.0.25->pygamma-agreement) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from cvxpy>=1.0.25->pygamma-agreement) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from cvxpy>=1.0.25->pygamma-agreement) (3.2.7.post2)
# Requirement already satisfied: decorator in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from numba>=0.54.0->pygamma-agreement) (0.44.0)
# Requirement already satisfied: pyYAML>=3.12 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pyannote.database>=4.1->pygamma-agreement) (6.0.2)
# Requirement already satisfied: typer>=0.12.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pyannote.database>=4.1->pygamma-agreement) (0.13.1)
# Requirement already satisfied: six>=1.5 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from hypothesis->cylp) (24.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: qdldl in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from osqp>=0.6.2->cvxpy>=1.0.25->pygamma-agreement) (0.1.7.post5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: click>=8.0.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database>=4.1->pygamma-agreement) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database>=4.1->pygamma-agreement) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from typer>=0.12.1->pyannote.database>=4.1->pygamma-agreement) (13.9.4)
# Requirement already satisfied: executing>=1.2.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.1->pygamma-agreement) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.1->pyannote.database>=4.1->pygamma-agreement) (0.1.2)
# WARNING: Ignoring invalid distribution ~llama (/home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~llama (/home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~llama (/home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~llama (/home/stefa/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Computing inter-annotator agreement (IAA) with factgenie
#
# This notebook shows how to compute inter-annotator agreement (IAA) between annotators.
#
# # Pearson r
#
# First, we will use the **Pearson correlation coefficient** to measure the agreement between two annotator groups.
#
# Specifically, we will measure how much the **error counts** agree.
#
# In the ideal case, both annotator groups annotated the **same amount of errors of each category** for each example. The Pearson r coefficient will help us to quantify to which extent it is true. The value of 1 signifies perfect *positive linear correlation*, 0 signifies no linear correlation, -1 signifies perfect *negative linear correllation*.

# %%
from scipy.stats import pearsonr
import numpy as np
import pandas as pd
import logging
import traceback


def compute_pearson_r(df, group1, group2):
    group1_data = df[df['annotator_group_id'] == group1]
    group2_data = df[df['annotator_group_id'] == group2]

    group1_counts = list(group1_data["count"])
    group2_counts = list(group2_data["count"])

    # Micro correlation - correlation of counts
    micro_corr = pearsonr(group1_counts, group2_counts)[0]

    # Macro correlation - average of per-type correlations
    type_corrs = []
    for ann_type in df['annotation_type'].unique():
        g1_type = list(group1_data[group1_data['annotation_type'] == ann_type]["count"])
        g2_type = list(group2_data[group2_data['annotation_type'] == ann_type]["count"])

        type_corrs.append(pearsonr(g1_type, g2_type)[0])

    macro_corr = np.mean(type_corrs)

    return {'micro': micro_corr, 'macro': macro_corr, 'category_correlations': type_corrs}

# def compute_pearson_r(df, group1, group2):
#     """
#     Compute Pearson correlation for two groups from a DataFrame
#     """
#
#     # Filter data for each group
#     group1_data = df[df["annotator_group_id"] == group1]
#     group2_data = df[df["annotator_group_id"] == group2]
#
#     # Ensure we align data between the two groups based on some common criteria (e.g., aligning by index or a shared column like 'type')
#     group1_data = group1_data.sort_values(by="annotation_type").reset_index(drop=True)
#     group2_data = group2_data.sort_values(by="annotation_type").reset_index(drop=True)
#
#     # Check for mismatched lengths and warn if needed
#     if len(group1_data) != len(group2_data):
#         print(f"Warning: Group lengths do not match for {group1} and {group2}. Aligning data to common types.")
#         common_types = set(group1_data["annotation_type"]).intersection(set(group2_data["annotation_type"]))
#         group1_data = group1_data[group1_data["annotation_type"].isin(common_types)].sort_values(by="annotation_type").reset_index(drop=True)
#         group2_data = group2_data[group2_data["annotation_type"].isin(common_types)].sort_values(by="annotation_type").reset_index(drop=True)
#
#     # Now extract counts
#     group1_counts = list(group1_data["count"])
#     group2_counts = list(group2_data["count"])
#
#     # Final check to ensure equal lengths
#     if len(group1_counts) != len(group2_counts):
#         raise ValueError(
#             f"After alignment, group counts are still mismatched: {len(group1_counts)} vs {len(group2_counts)}.")
#
#     # Micro correlation - correlation of counts
#     micro_corr = pearsonr(group1_counts, group2_counts)[0]
#
#     # Macro correlation - average of per-type correlations (dummy example, adjust logic as needed)
#     type_corrs = []
#     unique_types = set(group1_data["annotation_type"])
#     for t in unique_types:
#         g1_t = group1_data[group1_data["annotation_type"] == t]["count"].values
#         g2_t = group2_data[group2_data["annotation_type"] == t]["count"].values
#         if len(g1_t) and len(g2_t):
#             type_corrs.append(pearsonr(g1_t, g2_t)[0])
#
#     macro_corr = sum(type_corrs) / len(type_corrs) if type_corrs else None
#
#     return {"micro": micro_corr, "macro": macro_corr, 'category_correlations': type_corrs}

# %% [markdown]
# ### Input data
# For computing Pearson r, you will need (at least one of) the CSV files generated by factgenie:
# - `example_level_counts.csv` - absolute error counts for each (dataset, split, setup_id, example_idx) combination,
# - `dataset_level_counts.csv` - average error counts for each (dataset, split, setup_id) combination.
#
# You can generate these files on the `/analyze` page (on the Inter-annotator agreement tab). On that page, you need to select the campaign(s) with multiple annotators per example and select `Export data files`.

# %%
# Set the directory where the csv files are located here
csv_dir = "./factgenie/llm2"

level = "example"

csv_filename = f"{csv_dir}/{level}_level_counts.csv"
# Load data
df = pd.read_csv(csv_filename)

# %% [markdown]
# ### Annotator groups
# We will always compute the correlation between two **annotator groups**. Each annotator group has an id in the format `{campaign_id}-anngroup-{group_idx}`. That means that it uniquely defines the ordinal number of the annotator within a specific campaign.
#
# Example: in the campaign `llm-eval-1`, you used two annotators per example. Then you want to measure agreement between `llm-eval-1-anngroup-0` and `llm-eval-1-anngroup-1`.

# %%
# Use all annotator groups
annotator_groups = df.annotator_group_id.unique()

print(f"Groups: {annotator_groups}")

from itertools import combinations

group_pairs = list(combinations(annotator_groups, 2))
# or use a list of tuples: [("group1", "group2"), ...]

# group_pairs = [("highlights-b-longer-anngroup-30", "highlights-a-longer-anngroup-30")]

print(f"Group pairs: {group_pairs}")
# Out:
# Groups: ['llm-eval-3-anngroup-0' 'llm-eval-2-anngroup-0' 'campaign-1-anngroup-3'
#  'campaign-1-anngroup-1' 'campaign-1-anngroup-5' 'campaign-1-anngroup-2'
#  'campaign-1-anngroup-6' 'campaign-1-anngroup-7' 'campaign-1-anngroup-4'
#  'campaign-1-anngroup-8' 'campaign-1-anngroup-0' 'campaign-1-anngroup-9']
# Group pairs: [('llm-eval-3-anngroup-0', 'llm-eval-2-anngroup-0'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-3'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-1'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-5'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-2'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-6'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-7'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-4'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-8'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-0'), ('llm-eval-3-anngroup-0', 'campaign-1-anngroup-9'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-3'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-1'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-5'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-2'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-6'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-7'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-4'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-8'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-0'), ('llm-eval-2-anngroup-0', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-1'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-5'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-2'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-6'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-7'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-3', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-5'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-2'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-6'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-7'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-1', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-2'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-6'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-7'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-5', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-6'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-7'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-2', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-6', 'campaign-1-anngroup-7'), ('campaign-1-anngroup-6', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-6', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-6', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-6', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-7', 'campaign-1-anngroup-4'), ('campaign-1-anngroup-7', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-7', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-7', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-4', 'campaign-1-anngroup-8'), ('campaign-1-anngroup-4', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-4', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-8', 'campaign-1-anngroup-0'), ('campaign-1-anngroup-8', 'campaign-1-anngroup-9'), ('campaign-1-anngroup-0', 'campaign-1-anngroup-9')]

# %% [markdown]
# ### Average type
# - **Micro-average** - a coefficient computed over concatenated results from all the categories.
# - **Macro-average** - an average of coefficients computed separately for each category.

# %%
# Compute correlations for all pairs of groups
for group1, group2 in group_pairs:
    correlations = compute_pearson_r(df, group1, group2)

    print(f"{level}-level correlations between {group1} and {group2}")
    print("==============================================")

    print(f"Micro Pearson-r: {correlations['micro']:.3f}")
    print("==============================================")

    for i, corr in enumerate(correlations['category_correlations']):
        print(f"Category {i}: {corr:.3f}")
    print("----------------------------------------------")

    print(f"Macro Pearson-r: {correlations['macro']:.3f}")
    print("==============================================")
# Out:
# example-level correlations between llm-eval-3-anngroup-0 and llm-eval-2-anngroup-0
# ==============================================
# Micro Pearson-r: 0.338
# ==============================================
# Category 0: 0.268
# Category 1: nan
# Category 2: 0.702
# Category 3: nan
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-3
# ==============================================
# Micro Pearson-r: 0.364
# ==============================================
# Category 0: 0.527
# Category 1: nan
# Category 2: -0.019
# Category 3: 0.233
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-1
# ==============================================
# Micro Pearson-r: 0.412
# ==============================================
# Category 0: 0.757
# Category 1: nan
# Category 2: 0.697
# Category 3: -0.047
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-5
# ==============================================
# Micro Pearson-r: 0.083
# ==============================================
# Category 0: 0.128
# Category 1: nan
# Category 2: 0.486
# Category 3: 0.026
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-2
# ==============================================
# Micro Pearson-r: 0.429
# ==============================================
# Category 0: 0.603
# Category 1: nan
# Category 2: 0.329
# Category 3: 0.281
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-6
# ==============================================
# Micro Pearson-r: 0.406
# ==============================================
# Category 0: 0.630
# Category 1: nan
# Category 2: 0.256
# Category 3: 0.267
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-7
# ==============================================
# Micro Pearson-r: 0.178
# ==============================================
# Category 0: 0.446
# Category 1: nan
# Category 2: 0.231
# Category 3: -0.061
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-4
# ==============================================
# Micro Pearson-r: 0.292
# ==============================================
# Category 0: 0.606
# Category 1: nan
# Category 2: 0.486
# Category 3: 0.149
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# example-level correlations between llm-eval-3-anngroup-0 and campaign-1-anngroup-8
# ==============================================
# Micro Pearson-r: 0.458
# ==============================================
# Category 0: 0.714
# Category 1: nan
# Category 2: 0.231
# Category 3: 0.243
# ----------------------------------------------
# Macro Pearson-r: nan
# ==============================================
# /tmp/ipykernel_19318/2647288740.py:24: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   type_corrs.append(pearsonr(g1_type, g2_type)[0])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19318/2991619041.py in ?()
#       1 # Compute correlations for all pairs of groups
#       2 for group1, group2 in group_pairs:
# ----> 3     correlations = compute_pearson_r(df, group1, group2)
#       4
#       5     print(f"{level}-level correlations between {group1} and {group2}")
#       6     print("==============================================")
#
# /tmp/ipykernel_19318/2647288740.py in ?(df, group1, group2)
#      12     group1_counts = list(group1_data["count"])
#      13     group2_counts = list(group2_data["count"])
#      14
#      15     # Micro correlation - correlation of counts
# ---> 16     micro_corr = pearsonr(group1_counts, group2_counts)[0]
#      17
#      18     # Macro correlation - average of per-type correlations
#      19     type_corrs = []
#
# ~/IdeaProjects/tesi_tln/venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py in ?(x, y, alternative, method)
#    4717
#    4718     """
#    4719     n = len(x)
#    4720     if n != len(y):
# -> 4721         raise ValueError('x and y must have the same length.')
#    4722
#    4723     if n < 2:
#    4724         raise ValueError('x and y must have length at least 2.')
#
# ValueError: x and y must have the same length.

# %% [markdown]
# # Gamma (γ) score
# Next, we compute the gamma (γ) score.
#
# This score suitable for computing IAA in cases where are both (1) determining span positions and (2) categorizing the spans.
#
# The γ score considers the best alignment between the spans and computes the value based on the number of local dissimilarities. The score will help us to quantify the correlation not just between the error counts, but also their exact **positions** on top of the output text.
#
# For full description, please refer to the original paper [Mathet et al. (2015)](https://doi.org/10.1162/COLI_a_00227).
#
# For Python, the score is implemented in the [pygamma-agreement](https://pygamma-agreement.readthedocs.io/en/latest/index.html) library.
#
# **Note that computing the score is computationally intensive. Consider saving intermediate per-example scores in case you need to repeat the experiments.**

# %%
from IPython import display
import pygamma_agreement as pa
from pyannote.core import Segment
from tqdm.notebook import tqdm

def compute_gamma(span_index, dissim):
    gamma_scores = []
    running_avg = 0
    
    # Group examples
    groups = list(span_index.groupby(["dataset", "split", "setup_id", "example_idx"]))
    
    # Create progress bar
    pbar = tqdm(total=len(groups), desc='Computing gamma score')
    

    display.display(f"Visualization of the best alignment", display_id='vis_lbl')
    display.display(f"Waiting for the first example...", display_id='vis')

    for idx, (i, group) in enumerate(groups, 1):
        try:
            # Add each annotation to continuum
            continuum = pa.Continuum()

            if group.annotator_group_id.unique().shape[0] < 2:
                # One of the annotators did not add any annotation -> gamma = 0
                print(f"Example {idx} has annotations from only one annotator group")
                gamma_scores.append(0.0)
                running_avg = np.mean(gamma_scores)
                pbar.set_postfix({'avg_gamma': f'{running_avg:.3f}'})
                pbar.update(1)
                continue

            for j, row in group.iterrows():
                # make sure we do not add empty segments
                if row["annotation_start"] == row["annotation_end"]:
                    continue

                continuum.add(
                    str(row["annotator_group_id"]),
                    Segment(row["annotation_start"], row["annotation_end"]),
                    str(row["annotation_type"]),
                )

            # Temporarily increase logging level to suppress output
            logging.getLogger().setLevel(logging.WARNING)
            gamma_results = continuum.compute_gamma(dissim, soft=True)
            logging.getLogger().setLevel(logging.INFO)

            # Show the best alignment for every 10th example
            if pbar.n % 10 == 0:
                display.update_display(f"Visualization of the best alignment for example {idx}", display_id='vis_lbl')
                display.update_display(gamma_results.best_alignment, display_id='vis')

            gamma_scores.append(gamma_results.gamma)
            running_avg = np.mean(gamma_scores)
            
            # Update progress bar with current average
            pbar.set_postfix({'avg_gamma': f'{running_avg:.3f}'})
            pbar.update(1)
        except Exception as e:
            traceback.print_exc()
            print(f"Error computing gamma for example {idx}")
            gamma_scores.append(0.0)
            running_avg = np.mean(gamma_scores)
            pbar.set_postfix({'avg_gamma': f'{running_avg:.3f}'})
            pbar.update(1)
    
    pbar.close()
    return float(np.mean(gamma_scores)) if gamma_scores else 0.0
